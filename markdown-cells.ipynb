# %% [markdown]
# $y = mx + b$

# %% [markdown]
# $$
# test
# $$

# %% [markdown]
# |col1   |col2  |col3  |
# |-------|:----:|-----:|

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,1,300)
for w in range(2,6,2):
plt.plot(x,np.sin(np.pi*x)*np.sin(2*w*np.pi*x))

# %%
# %%time

def hello(x):
    print('xin chào',x)

hello('A')
# Out:
# xin chào A
# Wall time: 999 µs

# %%
# %%writefile test2.ipynb
#
# def hello(x):
#     print('xin chào',x)
#
# hello('A')
# Out:
# Writing test2.ipynb

# %%
# %pycat test.ipynb

# %%
# %pycat prj1-explore-weather-trends.ipynb
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "id": "4e6b4c83",
#    "metadata": {},
#    "source": [
#     "#### Outline"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "d2e576a1",
#    "metadata": {},
#    "source": [
#     "1. What tools did i use? <br>\n",
#     "Step 1: Used SQL to extract data into a csv file, then downloaded it <br>\n",
#     "Step 2: Uploaded the csv file into Python, did all the calculation and visualization using Python <br>\n",
#     "<br>\n",
#     "```\n",
#     "SELECT\n",
#     "    'LOCAL' \"TYPE\",\n",
#     "    YEAR,\n",
#     "    AVG_TEMP\n",
#     "FROM CITY_DATA\n",
#     "WHERE CITY='HANOI'\n",
#     "\n",
#     "UNION ALL\n",
#     "\n",
#     "SELECT\n",
#     "    'GLOBAL' \"TYPE\",\n",
#     "    YEAR,\n",
#     "    AVG_TEMP\n",
#     "FROM GLOBAL_DATA\n",
#     "```"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "247eb4c6",
#    "metadata": {},
#    "source": [
# ...

# %%
abc
# Out:
# 'test if it works'

# %%
abc
# Out:
# 'test if it works'
